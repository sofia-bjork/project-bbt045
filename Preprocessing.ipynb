# %% [markdown]
# # Preprocessing the RNA-seq subset_data
#
# Setting up relevant directories for the subset RNA-seq data

# %%
# %%bash
#
# mkdir -p data
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data
# mkdir -p subset_rawdata_RNA-seq
# mkdir -p subset_trimmed_RNA-seq
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory

# %% [markdown]
# # Selecting the RNA-seq files and creating a symlink to the data for the subset of Hp and Atr

# %%
# %%bash
#
# # Extract IDs for 'Atr' and 'Hp'nfrom the RNA-seq-list.txt file
# Hp_ids=($(grep -P '(Atr|Hp)' /cephyr/NOBACKUP/groups/bbt045_2025/Projects/Data/RNA-seq-list.txt | awk '{print $1}'))
#
# # Define directories
# source_dir="/cephyr/NOBACKUP/groups/bbt045_2025/Projects/Data/RNAseq"
# destination_dir="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_rawdata_RNA-seq"
#
# # Loop through extracted IDs
# for id in "${Hp_ids[@]}"; do
#     # Store both file paths in an array
#     files=("$source_dir/${id}_1.fastq.gz.subset.fastq.gz" "$source_dir/${id}_2.fastq.gz.subset.fastq.gz")
#
#     # Loop through each file
#     for file in "${files[@]}"; do
#         if [[ -f "$file" ]]; then
#             ln -s -t "$destination_dir" "$file"
#         else
#             echo "File $file not found!"
#         fi
#     done
# done
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory

# %% [markdown]
# Skriv

# %%
# %%bash
#
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_rawdata_RNA-seq
# mkdir -p fastqc_subset_rawdata
# fastqc -o fastqc_subset_rawdata *.fastq.gz > /dev/null
#
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_rawdata_RNA-seq/fastqc_subset_rawdata
# multiqc . > /dev/null
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory
# Started analysis of ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 5% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 10% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 15% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 20% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 25% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 30% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 35% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 40% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 45% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 50% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 55% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# Approx 60% complete for ERR950158_1.fastq.gz.subset.fastq.gz
# ...

# %% [markdown]
# skriv

# %%
# %%bash
#
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_rawdata_RNA-seq
# mkdir -p ../subset_trimmed_RNA-seq  # Create output directory if it doesn't exist
#
# for file in *_1.fastq.gz.subset.fastq.gz; do
#   # Extract the base filename (remove _1.fastq.gz.subset.fastq.gz)
#   base="${file%%_1.fastq.gz.subset.fastq.gz}"
#
#   # Define corresponding R2 file
#   file_R2="${base}_2.fastq.gz.subset.fastq.gz"
#
#   # Run Cutadapt for paired-end reads
#   cutadapt \
#     -a AGATCGGAAGAG -A AGATCGGAAGAG \
#     --minimum-length 25 \
#     -o /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_trimmed_RNA-seq/"${base}_trimmed_1.fastq.gz" \
#     -p /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_trimmed_RNA-seq/"${base}_trimmed_2.fastq.gz" \
#     "$file" "$file_R2" > /dev/null
# done
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory

# %% [markdown]
# skriv

# %%
# %%bash
#
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_trimmed_RNA-seq
# mkdir -p fastqc_subset_trimmed
# fastqc -o fastqc_subset_trimmed *.fastq.gz > /dev/null
#
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_trimmed_RNA-seq/fastqc_subset_trimmed
# multiqc . > /dev/null
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory
# Started analysis of ERR950158_trimmed_1.fastq.gz
# Approx 5% complete for ERR950158_trimmed_1.fastq.gz
# Approx 10% complete for ERR950158_trimmed_1.fastq.gz
# Approx 15% complete for ERR950158_trimmed_1.fastq.gz
# Approx 20% complete for ERR950158_trimmed_1.fastq.gz
# Approx 25% complete for ERR950158_trimmed_1.fastq.gz
# Approx 30% complete for ERR950158_trimmed_1.fastq.gz
# Approx 35% complete for ERR950158_trimmed_1.fastq.gz
# Approx 40% complete for ERR950158_trimmed_1.fastq.gz
# Approx 45% complete for ERR950158_trimmed_1.fastq.gz
# Approx 50% complete for ERR950158_trimmed_1.fastq.gz
# Approx 55% complete for ERR950158_trimmed_1.fastq.gz
# Approx 60% complete for ERR950158_trimmed_1.fastq.gz
# Approx 65% complete for ERR950158_trimmed_1.fastq.gz
# Approx 70% complete for ERR950158_trimmed_1.fastq.gz
# ...

# %% [markdown]
# # Preprocessing for RNA-seq data

# %%
# %%bash
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data
# mkdir -p rawdata_RNA-seq
# mkdir -p trimmed_RNA-seq
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory

# %% [markdown]
# # Selecting the RNA-seq files and creating a symlink to the data for Hp and Atr

# %%
# %%bash
#
# # Extract IDs for 'Atr' and 'Hp'nfrom the RNA-seq-list.txt file
# Hp_ids=($(grep -P '(Atr|Hp)' /cephyr/NOBACKUP/groups/bbt045_2025/Projects/Data/RNA-seq-list.txt | awk '{print $1}'))
#
# # Define directories
# source_dir="/cephyr/NOBACKUP/groups/bbt045_2025/Projects/Data/RNAseq"
# destination_dir="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/rawdata_RNA-seq"
#
# # Loop through extracted IDs
# for id in "${Hp_ids[@]}"; do
#     # Store both file paths in an array
#     files=("$source_dir/${id}_1.fastq.gz" "$source_dir/${id}_2.fastq.gz")
#
#     # Loop through each file
#     for file in "${files[@]}"; do
#         if [[ -f "$file" ]]; then
#             ln -s -t "$destination_dir" "$file"
#         else
#             echo "File $file not found!"
#         fi
#     done
# done
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory

# %% [markdown]
# # Write in a Sbatch scripts (below) - note to myself

# %%
# %%bash
# #fastqc for rawdata
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/rawdata_RNA-seq
# mkdir -p fastqc_rawdata
# fastqc -o fastqc_rawdata *.fastq.gz > /dev/null
# #multiqc for fastqc reports from rawdata
# cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/rawdata_RNA-seq/fastqc_rawdata
# multiqc . > /dev/null
# Out:
# /usr/share/lmod/lmod/init/bash: /usr/share/lmod/lmod/libexec/addto: /usr/bin/lua: bad interpreter: No such file or directory
# Started analysis of ERR950158_1.fastq.gz
# Approx 5% complete for ERR950158_1.fastq.gz
# Approx 10% complete for ERR950158_1.fastq.gz
# Approx 15% complete for ERR950158_1.fastq.gz
# Approx 20% complete for ERR950158_1.fastq.gz
# Approx 25% complete for ERR950158_1.fastq.gz
# Approx 30% complete for ERR950158_1.fastq.gz
# Approx 35% complete for ERR950158_1.fastq.gz
# Approx 40% complete for ERR950158_1.fastq.gz
# Approx 45% complete for ERR950158_1.fastq.gz
# Approx 50% complete for ERR950158_1.fastq.gz
# Approx 55% complete for ERR950158_1.fastq.gz
# Approx 60% complete for ERR950158_1.fastq.gz
# Approx 65% complete for ERR950158_1.fastq.gz
# Approx 70% complete for ERR950158_1.fastq.gz
# Approx 75% complete for ERR950158_1.fastq.gz
# Approx 80% complete for ERR950158_1.fastq.gz
# Approx 85% complete for ERR950158_1.fastq.gz
# ...

# %%
#Trimming off adaptors
cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/rawdata_RNA-seq
mkdir -p ../trimmed_RNA-seq  # Create output directory if it doesn't exist

for file in *_1.fastq.gz; do
  # Extract the base filename (remove _1.fastq.gz.subset.fastq.gz)
  base="${file%%_1.fastq.gz}"
  
  # Define corresponding R2 file
  file_R2="${base}_2.fastq.gz"

  # Run Cutadapt for paired-end reads
  cutadapt \
    -a AGATCGGAAGAG -A AGATCGGAAGAG \
    --minimum-length 25 \
    -o /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/trimmed_RNA-seq/"${base}_trimmed_1.fastq.gz" \
    -p /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/trimmed_RNA-seq/"${base}_trimmed_2.fastq.gz" \
    "$file" "$file_R2" > /dev/null
done

# %%
#fastqc for trimmed data
cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/trimmed_RNA-seq
mkdir -p fastqc_trimmed
fastqc -o fastqc_trimmed *.fastq.gz > /dev/null
#multiqc for fastqc reports from trimmed data
cd /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/trimmed_RNA-seq/fastqc_trimmed
multiqc . > /dev/null

# %%
# Define paths
GENOME_DIR="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/STAR_index"
FASTQ_DIR="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/subset_trimmed_RNA-seq/"
OUTPUT_DIR="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/alignment_STAR_subset"

# Create output directory if it doesn't exist
mkdir -p "$OUTPUT_DIR"

# Loop through FASTQ files
for file1 in ${FASTQ_DIR}/*_1.fastq.gz; do
    # Extract sample name
    SAMPLE=$(basename "$file1" _1.fastq.gz)
    file2="${FASTQ_DIR}/${SAMPLE}_2.fastq.gz"

    # Run STAR alignment
    STAR --runThreadN 8 \
         --genomeDir "$GENOME_DIR" \
         --readFilesIn "$file1" "$file2" \
         --readFilesCommand zcat \
         --outFileNamePrefix "${OUTPUT_DIR}/${SAMPLE}_" \
         --sjdbGTFfile /cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/human_genome/Homo_sapiens.GRCh38.113.gtf \
         --outSAMtype BAM SortedByCoordinate \
         --quantMode TranscriptomeSAM GeneCounts
done

# %%
# Set variables
gtf_file="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/human_genome/Homo_sapiens.GRCh38.113.gtf"
output_dir="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/CN_gene_counts_TEST"
aligned_dir="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/alignment_STAR_subset/"

# Create output directory if it does not exist
mkdir -p "$output_dir"


# Loop through BAM files
for bam_file in ${aligned_dir}/*sortedByCoord.out.bam; do
    # Extract sample name
    SAMPLE=$(basename "$bam_file" _Aligned.sortedByCoord.out.bam)
    
    # Define output files
    sorted_bam_file="$output_dir/${SAMPLE}_sorted.bam"
    output_file="$output_dir/${SAMPLE}_htseq_counts.txt"
    log_file="$output_dir/${SAMPLE}_htseq-count.log"

    # Sort BAM file by name for htseq-count
    samtools sort -n -o "$sorted_bam_file" "$bam_file"

    # Check if samtools sort was successful
    if [ $? -ne 0 ]; then
        echo "Error: samtools sort failed for $bam_file" >&2
        continue
    fi

    # Run htseq-count
    htseq-count -f bam -r name -s no -t exon -i gene_id "$sorted_bam_file" "$gtf_file" > "$output_file" 2> "$log_file"

    # Check if htseq-count ran successfully
    if [ $? -eq 0 ]; then
        echo "htseq-count completed successfully. Output saved in $output_file"
    else
        echo "htseq-count failed for $bam_file. Check log file at $log_file" >&2
        echo "htseq-count log:"
        cat "$log_file"
    fi

done

# %%
count_dir="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/CN_gene_counts_TEST"
sub_dir_count="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/CN_gene_counts_TEST/sub_dir_count"

mkdir -p "$sub_dir_count"

# Move BAM and log files to the sub-directory
for file in "$count_dir"/*_sorted.bam "$count_dir"/*.log; do
    if [ -e "$file" ]; then  # Check if the file exists
        mv "$file" "$sub_dir_count/"
    fi
done

echo "Files moved successfully to $sub_dir_count"

# %%
# Define input directory containing the count files
input_dir="/cephyr/NOBACKUP/groups/bbt045_2025/groups/group_Bjork/data/CN_gene_counts_TEST"

# Define output file
output_file="$input_dir/merged_counts.txt"

# Get list of count files
count_files=("$input_dir"/*_trimmed_htseq_counts.txt)

# Check if there are count files
if [ ${#count_files[@]} -eq 0 ]; then
    echo "Error: No count files found in $input_dir" >&2
    exit 1
fi

# Use the first file as a reference to check gene consistency
first_file="${count_files[0]}"
awk '{print $1}' "$first_file" | sort > /tmp/gene_list_reference.txt

# Merge files based on first column
awk -v ref_file="/tmp/gene_list_reference.txt" '
    BEGIN { OFS="\t"; while ((getline < ref_file) > 0) ref_genes[$1] = 1; close(ref_file) }
    FNR==1 { files++ }  # Track number of files
    {
        gene_id = $1
        count = $2
        if (!(gene_id in ref_genes)) {
            print "Error: Gene " gene_id " is missing from one or more files!" > "/dev/stderr"
            exit 1
        }
        counts[gene_id, FILENAME] = count
        genes[gene_id]  # Store unique gene IDs
    }
    END {
        # Print header
        printf "Gene_ID"
        for (i in ARGV) {
            if (ARGV[i] ~ /_trimmed_htseq_counts.txt$/) {
                sample_name = ARGV[i]
                sub(".*/", "", sample_name)  # Remove path
                sub("_trimmed_htseq_counts.txt", "", sample_name)  # Extract sample ID
                printf "\t%s", sample_name
            }
        }
        print ""

        # Print merged counts
        for (gene in genes) {
            split(gene, arr, SUBSEP)
            printf "%s", arr[1]  # Print gene ID
            for (i in ARGV) {
                if (ARGV[i] ~ /_trimmed_htseq_counts.txt$/) {
                    file = ARGV[i]
                    printf "\t%s", (counts[arr[1], file] ? counts[arr[1], file] : 0)
                }
            }
            print ""
        }
    }
' "${count_files[@]}" > "$output_file"

echo "Merged file saved as: $output_file"
